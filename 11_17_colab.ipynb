# %%
#os 환경
# !cat /etc/issue.net
# Out:
# Ubuntu 18.04.5 LTS

# %%
# !head /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.184
# cache size	: 56320 KB
# physical id	: 0

# %%
# !head /proc/meminfo
# Out:
# MemTotal:       13302924 kB
# MemFree:        10862280 kB
# MemAvailable:   12505836 kB
# Buffers:          118088 kB
# Cached:          1677840 kB
# SwapCached:            0 kB
# Active:           946076 kB
# Inactive:        1279840 kB
# Active(anon):     396244 kB
# Inactive(anon):      432 kB

# %%
# !python --version
# Out:
# Python 3.7.12

# %%
#GPU 사용시 하드웨어 가속기 설정: 수정 > 노트설정 > 하드웨어 가속기 > GPU

# %%
print("안녕하세요")
# Out:
# 안녕하세요

# %% [markdown]
# ## Colab : Colaboratory
# 구글에서 **교육과 과학연구 목적**으로 개발한 도구

# %% [markdown]
# ##파일 업로드하기

# %%
# 직접 파일 업로드
from google.colab import files
files.upload()
# myfile = files.upload()
# Out:
#      <input type="file" id="files-518efd40-0b91-40e2-84a6-401906818f7e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-518efd40-0b91-40e2-84a6-401906818f7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-5c2e8a8d365b> in <module>()
#       1 from google.colab import files
# ----> 2 files.upload()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 64           input_id=input_id, output_id=output_id))
# ...

# %%
import io
import pandas as pd

# %%
data = pd.read_csv('/content/h_p_clean.csv')

# %%
data.head()
# Out:
#    지역             규모    연도   월   분양가
# 0  서울          60㎡이하  2015  10  5652
# 1  서울    60㎡초과 85㎡이하  2015  10  5882
# 2  서울   85㎡초과 102㎡이하  2015  10  5721
# 3  서울         102㎡초과  2015  10  5879
# 4  인천          60㎡이하  2015  10  3488

# %%
# 드라이브에서 가져오는 방법
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filename = '/content/drive/MyDrive/Colab Notebooks/h_p_clean.csv'

# %%
data = pd.read_csv(filename)

# %%
data.head()
# Out:
#    지역             규모    연도   월   분양가
# 0  서울          60㎡이하  2015  10  5652
# 1  서울    60㎡초과 85㎡이하  2015  10  5882
# 2  서울   85㎡초과 102㎡이하  2015  10  5721
# 3  서울         102㎡초과  2015  10  5879
# 4  인천          60㎡이하  2015  10  3488

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo('bEtwRv2Iiig', 600, 380)
